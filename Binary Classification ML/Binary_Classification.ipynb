# %% [markdown]
# # Binary Classification: Telcom company Customer Churn Classification
# ## Problem Statement :
#
# In the telecom industry, customers are able to choose from a pool of companies to cater their needs regarding communication and internet. Customers are very critical about the kind of services they receive and judge the enitre company based on a single experience! These communication services have become so recurrent and inseparable from the daily routine that a 30 minute maintenance break kicks in anxiety in the users highlighting our taken-for-granted attitude towards these services! Coupled with high customer acquisation costs, churn analysis becomes very pivotal! Churn rate is a metric that describes the number of customers that cancelled or did not renew their subscription with the company. Thus, higher the churn rate, more customers stop buying from your business, directly affecting the revenue! Hence, based on the insights gained from the churn analysis, companies can build strategies, target segments, improve the quality of the services being provided to improve the customer experience, thus cultivating trust with the customers. That is why building predictive models and creating reports of churn analysis becomes key that paves the way for growth!
#
# ## Aim :
# - To classify the potential churn customers based on numerical and categorical features.
# - It is a **binary classification** problem for an imbalanced dataset.
#
# ## Dataset Attributes
#
# - **customerID** : Customer ID
# - **gender** : Whether the customer is a male or a female
# - **SeniorCitizen** : Whether the customer is a senior citizen or not (1, 0)
# - **Partner** : Whether the customer has a partner or not (Yes, No)
# - **Dependents** : Whether the customer has dependents or not (Yes, No)
# - **tenure** : Number of months the customer has stayed with the company
# - **PhoneService** : Whether the customer has a phone service or not (Yes, No)
# - **MultipleLines** : Whether the customer has multiple lines or not (Yes, No, No phone service)
# - **InternetService** : Customer’s internet service provider (DSL, Fiber optic, No)
# - **OnlineSecurity** : Whether the customer has online security or not (Yes, No, No internet service)
# - **OnlineBackup** : Whether the customer has online backup or not (Yes, No, No internet service)
# - **DeviceProtection** : Whether the customer has device protection or not (Yes, No, No internet service)
# - **TechSupport** : Whether the customer has tech support or not (Yes, No, No internet service)
# - **StreamingTV** : Whether the customer has streaming TV or not (Yes, No, No internet service)
# - **StreamingMovies** : Whether the customer has streaming movies or not (Yes, No, No internet service)
# - **Contract** : The contract term of the customer (Month-to-month, One year, Two year)
# - **PaperlessBilling** : Whether the customer has paperless billing or not (Yes, No)
# - **PaymentMethod** : The customer’s payment method (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic))
# - **MonthlyCharges** : The amount charged to the customer monthly
# - **TotalCharges** : The total amount charged to the customer
# - **Churn** : Whether the customer churned or not (Yes or No)

# %% [markdown]
# # Load dataset

# %%
#importing the dataset
import pandas as pd
telecom_dataFrame = pd.read_csv("train.csv")
telecom_dataFrame
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     9313-QOLTZ    Male              0      No         No      26
# 1     6654-QGBZZ  Female              0      No         No       1
# 2     6877-LGWXO    Male              1     Yes         No      18
# 3     8020-BWHYL  Female              1      No         No      15
# 4     3594-IVHJZ  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 6333  0684-AOSIH    Male              0     Yes         No       1
# 6334  5982-PSMKW  Female              0     Yes        Yes      23
# 6335  8044-BGWPI    Male              0     Yes        Yes      12
# 6336  7450-NWRTR    Male              1      No         No      12
# 6337  4795-UXVCJ    Male              0      No         No      26
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 0             Yes            No              No  No internet service  ...
# ...

# %% [markdown]
# #### Understanding the data

# %%
telecom_dataFrame.shape
# Out:
# (6338, 21)

# %%
telecom_dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6338 entries, 0 to 6337
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        6338 non-null   object
#  1   gender            6338 non-null   object
#  2   SeniorCitizen     6338 non-null   int64
#  3   Partner           6338 non-null   object
#  4   Dependents        6338 non-null   object
#  5   tenure            6338 non-null   int64
#  6   PhoneService      6338 non-null   object
#  7   MultipleLines     6338 non-null   object
#  8   InternetService   6338 non-null   object
#  9   OnlineSecurity    6338 non-null   object
#  10  OnlineBackup      6338 non-null   object
#  11  DeviceProtection  6338 non-null   object
#  12  TechSupport       6338 non-null   object
#  13  StreamingTV       6338 non-null   object
#  14  StreamingMovies   6338 non-null   object
#  15  Contract          6338 non-null   object
# ...

# %% [markdown]
# # Questions
# **Instructions:**
# 1.  Answer all questions.
# 2.  Justify your answers with appropriate reasoning, code, or calculations.
# 3.  Ensure your code is well-commented to explain your logic.
# 4.  Total Marks: 100

# %% [markdown]
# ## Data Analysis
# Summarize the data. How much data is present? What attributes/features are continuous valued? Which attributes are categorical?
#
# Display the statistical values for each of the attributes, of the distributions for each attribute. Explain noticeable traits for key attributes. Are there any attributes that might require special treatment? If so, what special treatment might they require?
#
# Analyze and discuss the relationships between the data attributes, and between the data attributes and label.
#
# Analyze the relationship between all the features. Use appropriate visualization techniques.

# %%
import pandas as pd

# Summarize the data
print("Summary of the data:")
print("Number of entries:", len(telecom_dataFrame))
print("Number of attributes/features:", len(telecom_dataFrame.columns))

# Identify continuous valued features
print("\nContinuous valued features:")
continuous_features = telecom_dataFrame.select_dtypes(include=['float64', 'int64']).columns
print(continuous_features)

# Identify categorical features
print("\nCategorical features:")
categorical_features = telecom_dataFrame.select_dtypes(include=['object']).columns
print(categorical_features)

# Displaying the statistical summary for continuous and categorical features
print("Statistical Summary for Continuous Features:")
display(telecom_dataFrame[continuous_features].describe())

print("\nStatistical Summary for Categorical Features:")
display(telecom_dataFrame[categorical_features].astype('object').describe())
# Out:
# Summary of the data:
# Number of entries: 6338
# Number of attributes/features: 21
#
# Continuous valued features:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges'], dtype='object')
#
# Categorical features:
# Index(['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges',
#        'Churn'],
#       dtype='object')
# Statistical Summary for Continuous Features:
#        SeniorCitizen       tenure  MonthlyCharges
# count    6338.000000  6338.000000     6338.000000
# mean        0.161723    32.358630       64.693760
# std         0.368226    24.537141       30.140955
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.450000
# 50%         0.000000    29.000000       70.300000
# ...

# %% [markdown]
# The dataset comprises 6,338 entries and 21 attributes/features. Among these, three features are continuous valued: 'SeniorCitizen', 'tenure', and 'MonthlyCharges'. These attributes describe numerical aspects such as the duration of tenure and monthly charges. Additionally, the dataset contains several categorical features, including 'gender', 'Partner', 'Dependents', 'PhoneService', and more, with 'Churn' indicating whether a customer churned or not.
#
# For the continuous features, the statistical summary reveals that 'tenure' has a mean of approximately 32.36 months, with a wide range from 0 to 72 months. 'MonthlyCharges' show a mean of around 64.69, with a standard deviation of 30.14, suggesting some variability in monthly charges among customers.
#
# Regarding categorical features, the summary showcases the distribution of unique values and their frequencies. For instance, 'gender' shows two unique categories with 'Male' being the most frequent. Similarly, 'Churn' indicates whether a customer churned, with 'No' being the dominant category.

# %% [markdown]
# Based on the statistical values provided, we can discern several notable traits among the attributes. 'SeniorCitizen' appears to have a relatively low mean, indicating a minority of customers being senior citizens. 'Tenure' displays a wide range of values, suggesting varying durations of customer relationships with the company. Meanwhile, 'MonthlyCharges' exhibit notable variability, indicating diverse pricing structures among customers. 'Churn', while not explicitly detailed, likely requires special treatment as the target variable in churn prediction models. These attributes may need preprocessing steps such as encoding for categorical variables like 'SeniorCitizen' and 'Churn', and scaling or normalization for continuous variables like 'Tenure' and 'MonthlyCharges' to ensure optimal performance in predictive modeling.

# %%
display(telecom_dataFrame.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  9313-QOLTZ    Male              0      No         No      26          Yes
# 1  6654-QGBZZ  Female              0      No         No       1          Yes
# 2  6877-LGWXO    Male              1     Yes         No      18          Yes
# 3  8020-BWHYL  Female              1      No         No      15          Yes
# 4  3594-IVHJZ  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0            No              No  No internet service  ...
# 1            No              No  No internet service  ...
# 2            No     Fiber optic                   No  ...
# 3            No     Fiber optic                   No  ...
# 4            No              No  No internet service  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# ...

# %%
# Change TotalCharges to float
telecom_dataFrame["TotalCharges"] = pd.to_numeric(telecom_dataFrame["TotalCharges"], errors="coerce")

# %%
telecom_dataFrame.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
telecom_dataFrame["PaymentMethod"].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Credit card (automatic)',
#        'Bank transfer (automatic)'], dtype=object)

# %%
# Delete "automatic" from PaymentMethod
telecom_dataFrame["PaymentMethod"] = telecom_dataFrame["PaymentMethod"].str.replace(" (automatic)", "", regex=False)

# %%
# Analyze relationships between all features using appropriate visualization techniques
import seaborn as sns
import matplotlib.pyplot as plt

print("\nVisualization of relationships between all features:")
sns.pairplot(telecom_dataFrame)
plt.show()
# Out:
# Visualization of relationships between all features:

# %% [markdown]
# From the visualization above, we observe that SeniorCitizen's are divided into two distinct sections, which indicate how tenure, MonthlyCharges and TotalCharges are calculated for people who are Senior Citizens and who are not. Similarly, wrt tenure, MonthlyCharges and TotalCharges, which displays relation with respect to each other. The visualization indicates distinct sections for senior citizens and non-senior citizens, shedding light on how attributes such as tenure, monthly charges, and total charges are calculated differently for each group. Additionally, it likely illustrates the relationship between tenure, monthly charges, and total charges, providing insights into how these factors interact with each other.

# %%
telecom_dataFrame['Churn'].value_counts()
# Out:
# No     4663
# Yes    1675
# Name: Churn, dtype: int64

# %%
plt.style.use("ggplot")
plt.figure(figsize=(5,5))
ax = sns.countplot(x = telecom_dataFrame["Churn"],palette="Blues")
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# Based on the target attribute, the number of people or count of Churned and not, is displayed

# %%
whether_not_churned = len(telecom_dataFrame[telecom_dataFrame['Churn']=='No'])
whether_churned = len(telecom_dataFrame[telecom_dataFrame['Churn']=='Yes'])
percent_of_no_churn = whether_not_churned/(whether_not_churned + whether_churned)
print("Percentage of customers not churned is", percent_of_no_churn*100)
percent_of_churn = whether_churned/(whether_not_churned+whether_churned)
print("Percentage of customers churned", percent_of_churn*100)
# Out:
# Percentage of customers not churned is 73.57210476491007
# Percentage of customers churned 26.42789523508993

# %%
display(telecom_dataFrame.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  9313-QOLTZ    Male              0      No         No      26          Yes
# 1  6654-QGBZZ  Female              0      No         No       1          Yes
# 2  6877-LGWXO    Male              1     Yes         No      18          Yes
# 3  8020-BWHYL  Female              1      No         No      15          Yes
# 4  3594-IVHJZ  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0            No              No  No internet service  ...
# 1            No              No  No internet service  ...
# 2            No     Fiber optic                   No  ...
# 3            No     Fiber optic                   No  ...
# 4            No              No  No internet service  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# Statistical values for each attribute
print("\nStatistical values for each attribute:")
print(telecom_dataFrame.describe())

import pandas as pd
#Replacing 'Yes' with 1 and 'No' with 0 in the 'Churn' column
telecom_dataFrame['Churn'] = telecom_dataFrame['Churn'].replace({'Yes': 1, 'No': 0})

# Calculate correlation between 'Churn' and other numeric columns
correlation_with_churn = telecom_dataFrame.corr()['Churn'].sort_values(ascending=False)

print("Correlation with Churn:")
print(correlation_with_churn)
# Out:
# Statistical values for each attribute:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    6338.000000  6338.000000     6338.000000   6327.000000
# mean        0.161723    32.358630       64.693760   2284.615845
# std         0.368226    24.537141       30.140955   2269.749306
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.450000    401.400000
# 50%         0.000000    29.000000       70.300000   1398.250000
# 75%         0.000000    55.000000       89.900000   3809.500000
# max         1.000000    72.000000      118.750000   8684.800000
# Correlation with Churn:
# Churn             1.000000
# MonthlyCharges    0.191290
# SeniorCitizen     0.152685
# TotalCharges     -0.195805
# tenure           -0.346667
# Name: Churn, dtype: float64

# %% [markdown]
# The provided statistical values for each attribute reveal several important observations. Firstly, the dataset consists of 6,338 entries. The mean values suggest that the average customer age for 'SeniorCitizen' is around 16%, while the mean tenure is approximately 32.36 months, with monthly charges averaging 64.69 dollars and total charges averaging $2,284.62. The standard deviations indicate notable variability within the dataset, particularly for 'Tenure' and 'TotalCharges'.
#
# Regarding correlations with 'Churn', we observe that 'Tenure' exhibits the strongest negative correlation (-0.347), suggesting that longer tenure is associated with lower churn rates. Conversely, 'MonthlyCharges' and 'TotalCharges' show weak positive and negative correlations, respectively, with 'Churn', indicating a less pronounced influence on customer churn. 'SeniorCitizen' displays a modest positive correlation (0.153) with 'Churn', suggesting that being a senior citizen might slightly increase the likelihood of churn.

# %%
display(telecom_dataFrame.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  9313-QOLTZ    Male              0      No         No      26          Yes
# 1  6654-QGBZZ  Female              0      No         No       1          Yes
# 2  6877-LGWXO    Male              1     Yes         No      18          Yes
# 3  8020-BWHYL  Female              1      No         No      15          Yes
# 4  3594-IVHJZ  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0            No              No  No internet service  ...
# 1            No              No  No internet service  ...
# 2            No     Fiber optic                   No  ...
# 3            No     Fiber optic                   No  ...
# 4            No              No  No internet service  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# ...

# %%
# Displaying th unique values in eachc feature
for feature in telecom_dataFrame.columns:
    unique_values = telecom_dataFrame[feature].unique()
    print(f"Unique values in {feature}: {unique_values}")
# Out:
# Unique values in customerID: ['9313-QOLTZ' '6654-QGBZZ' '6877-LGWXO' ... '8044-BGWPI' '7450-NWRTR'
#  '4795-UXVCJ']
# Unique values in gender: ['Male' 'Female']
# Unique values in SeniorCitizen: [0 1]
# Unique values in Partner: ['No' 'Yes']
# Unique values in Dependents: ['No' 'Yes']
# Unique values in tenure: [26  1 18 15  2 23 72 70 46 36  6  4 13 64  8 62 34 24 63 66 61 67 12 19
#   3 17 52 51  5 29 42 16 11 54 30  9  0 10 56 45 69 21 20  7 37 38 49 14
#  71 58 48 50 25 35 59 22 40 60 53 55 65 41 47 44 68 39 33 28 32 57 31 43
#  27]
# Unique values in PhoneService: ['Yes' 'No']
# Unique values in MultipleLines: ['No' 'Yes' 'No phone service']
# Unique values in InternetService: ['No' 'Fiber optic' 'DSL']
# Unique values in OnlineSecurity: ['No internet service' 'No' 'Yes']
# Unique values in OnlineBackup: ['No internet service' 'No' 'Yes']
# Unique values in DeviceProtection: ['No internet service' 'No' 'Yes']
# Unique values in TechSupport: ['No internet service' 'No' 'Yes']
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Categorical values
categorical_values = ["gender", "SeniorCitizen", "Partner", "Dependents", "PhoneService", "MultipleLines", 
                      "InternetService", "OnlineSecurity", "OnlineBackup", "DeviceProtection", "TechSupport", 
                      "StreamingTV", "StreamingMovies", "Contract", "PaymentMethod", "PaperlessBilling"]

# Numerical values
numerical_values = ["tenure", "MonthlyCharges", "TotalCharges"]

# Target value
target = "Churn"

# Filter DataFrame for target values 0 and 1
telecom_dataFrame_filtered = telecom_dataFrame[telecom_dataFrame[target].isin([0, 1])]

# Calculate the number of rows and columns for subplots for categorical values
num_columns_cat = 3
num_rows_cat = (len(categorical_values) + num_columns_cat - 1) // num_columns_cat

# Calculate the number of rows and columns for subplots for numerical values
num_columns_num = 3
num_rows_num = (len(numerical_values) + num_columns_num - 1) // num_columns_num

# Create subplots for categorical values
fig_cat, axes_cat = plt.subplots(num_rows_cat, num_columns_cat, figsize=(15, 5*num_rows_cat))
axes_cat = axes_cat.flatten()

# Loop through each categorical column and plot
for i, column in enumerate(categorical_values):
    sns.countplot(x=column, data=telecom_dataFrame_filtered, palette="Blues", ax=axes_cat[i], hue=target)
    axes_cat[i].set_title(column)

# Hide any unused subplots for categorical values
for j in range(len(categorical_values), len(axes_cat)):
    axes_cat[j].remove()

# Adjust layout to prevent overlap for categorical values
plt.tight_layout()

# Show the plot for categorical values
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def histogram_plots(df, numerical_values, target):
    for column in numerical_values:
        plt.figure(figsize=(8, 6))
        sns.histplot(data=df, x=column, hue=df[target], multiple="fill", palette="Set1", element="bars")
        plt.title(f'Distribution of {column} by {target}')
        plt.xlabel(column)
        plt.ylabel('Density')
        plt.legend(title=target, labels=["No Churn", "Churn"])
        plt.show()

numerical_values = ["tenure", "MonthlyCharges", "TotalCharges"]

histogram_plots(telecom_dataFrame, numerical_values, "Churn")

# %%
plt.figure(figsize=(10,6))
telecom_dataFrame.corr()["Churn"].sort_values(ascending=False).plot(kind="bar")
plt.savefig("correlation.png", dpi=300)
plt.show()

# %% [markdown]
# ## Data Pre-processing & Feature Engineering
# Discuss the steps you would take to clean and prepare the data for modeling. Justify why each step is necessary.
#
# Perform Feature Engineering on the dataset.
#
# Perform few statistical tests (Eg: ANOVA) on the dataset and Data Scaling, Sampling as needed. Based on that, check which columns can be eliminated.
#
# Check for any null values in the dataset and perform necessary actions. Also, encoding categorical columns necessarily.

# %% [markdown]
# #### checking the sum of missing values

# %%
telecom_dataFrame.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
display(telecom_dataFrame.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  9313-QOLTZ    Male              0      No         No      26          Yes
# 1  6654-QGBZZ  Female              0      No         No       1          Yes
# 2  6877-LGWXO    Male              1     Yes         No      18          Yes
# 3  8020-BWHYL  Female              1      No         No      15          Yes
# 4  3594-IVHJZ  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0            No              No  No internet service  ...
# 1            No              No  No internet service  ...
# 2            No     Fiber optic                   No  ...
# 3            No     Fiber optic                   No  ...
# 4            No              No  No internet service  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# ...

# %%
from sklearn.metrics import mutual_info_score

# function that computes the mutual information score between a categorical series and the column Churn
def compute_mutual_information(categorical_series):
    return mutual_info_score(categorical_series, telecom_dataFrame['Churn'])

# select categorical variables excluding the response variable 
categorical_variables = telecom_dataFrame.select_dtypes(include='object')

# compute the mutual information score between each categorical variable and the target
feature_importance = categorical_variables.apply(compute_mutual_information).sort_values(ascending=False)

# visualize feature importance
print(feature_importance)
# Out:
# customerID          0.577485
# Contract            0.096928
# OnlineSecurity      0.063540
# TechSupport         0.060567
# InternetService     0.054216
# OnlineBackup        0.045979
# DeviceProtection    0.043254
# PaymentMethod       0.042572
# StreamingMovies     0.031139
# StreamingTV         0.031104
# PaperlessBilling    0.019212
# Dependents          0.013959
# Partner             0.010555
# MultipleLines       0.000761
# gender              0.000068
# PhoneService        0.000048
# dtype: float64

# %% [markdown]
# Filling the columns with mean, if they have missing values

# %%
mean_total_charges = telecom_dataFrame['TotalCharges'].mean()
telecom_dataFrame.fillna(mean_total_charges,inplace=True)

# %% [markdown]
# LabelEncoding is a technique used to convert categorical attributes into numerical representations, assigning a unique integer to each category.

# %%
from sklearn.preprocessing import LabelEncoder

cat = telecom_dataFrame.select_dtypes(include='object')

label_encoder = LabelEncoder()
for col in cat:
    telecom_dataFrame[col]=label_encoder.fit_transform(telecom_dataFrame[col])

# %%
telecom_dataFrame.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0        5900       1              0        0           0      26
# 1        4246       0              0        0           0       1
# 2        4387       1              1        1           0      18
# 3        5102       0              1        0           0      15
# 4        2265       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             1              0                2               1  ...
# 1             1              0                2               1  ...
# 2             1              0                1               0  ...
# 3             1              0                1               0  ...
# 4             1              0                2               1  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 1            1            1                1         0
# ...

# %%
# Displaying unique values after LabelEncoding
for feature in telecom_dataFrame.columns:
    unique_values = telecom_dataFrame[feature].unique()
    print(f"Unique values in {feature}: {unique_values}")
# Out:
# Unique values in customerID: [5900 4246 4387 ... 5119 4739 3015]
# Unique values in gender: [1 0]
# Unique values in SeniorCitizen: [0 1]
# Unique values in Partner: [0 1]
# Unique values in Dependents: [0 1]
# Unique values in tenure: [26  1 18 15  2 23 72 70 46 36  6  4 13 64  8 62 34 24 63 66 61 67 12 19
#   3 17 52 51  5 29 42 16 11 54 30  9  0 10 56 45 69 21 20  7 37 38 49 14
#  71 58 48 50 25 35 59 22 40 60 53 55 65 41 47 44 68 39 33 28 32 57 31 43
#  27]
# Unique values in PhoneService: [1 0]
# Unique values in MultipleLines: [0 2 1]
# Unique values in InternetService: [2 1 0]
# Unique values in OnlineSecurity: [1 0 2]
# Unique values in OnlineBackup: [1 0 2]
# Unique values in DeviceProtection: [1 0 2]
# Unique values in TechSupport: [1 0 2]
# Unique values in StreamingTV: [1 0 2]
# Unique values in StreamingMovies: [1 2 0]
# Unique values in Contract: [0 2 1]
# Unique values in PaperlessBilling: [0 1]
# Unique values in PaymentMethod: [3 2 1 0]
# ...

# %%
telecom_dataFrame.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Compute correlation matrix
correlation = telecom_dataFrame.corr()['Churn'].abs()

# Select columns with correlation coefficient lower than 0.1
low_correl = correlation[correlation < 0.1].index

# Drop columns with low correlation
data = telecom_dataFrame.drop(columns=low_correl)

# Print remaining columns
print(data.columns)
# Out:
# Index(['SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# In addition to LabelEncoding, the correlation between all attributes was evaluated, and columns with correlations less than 0.1 were dropped. This process aids in focusing solely on the most relevant columns, streamlining the dataset and potentially enhancing the efficiency and effectiveness of subsequent analysis or modeling tasks.

# %%
from sklearn.preprocessing import MinMaxScaler

# Columns to be scaled using MinMaxScaler
features_to_scale = ["tenure", "MonthlyCharges", "TotalCharges"]

# Extract numerical features for scaling
numerical_features = telecom_dataFrame[features_to_scale]

# Apply MinMaxScaler to scale numerical features
scaler = MinMaxScaler()
scaled_numerical_features = scaler.fit_transform(numerical_features)
scaled_numerical_features_df = pd.DataFrame(scaled_numerical_features, columns=features_to_scale)

# Replace the original numerical features with the scaled ones
telecom_dataFrame[features_to_scale] = scaled_numerical_features_df

# Print the DataFrame to verify the changes
print(telecom_dataFrame.head())

# %%
plt.figure(figsize=(10,6))
telecom_dataFrame.corr()["Churn"].sort_values(ascending=False).plot(kind="bar")
plt.savefig("correlation.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the size of the figure
plt.figure(figsize=(12, 10))

# Check the correlation matrix of all features
telecom_dataFrame_corr = telecom_dataFrame.corr()

# Plot the heatmap
sns.heatmap(telecom_dataFrame_corr, annot=True, cmap='coolwarm')

# Set title and labels
plt.title('Correlation Matrix')
plt.xlabel('Features')
plt.ylabel('Features')

# Show the plot
plt.show()

# %% [markdown]
# From the correlation matrix, we observe that 'tenure' and 'TotalCharges' correlate the most, whereas the attributes 'Churn' and 'Contract' correlate the least

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6338 entries, 0 to 6337
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SeniorCitizen     6338 non-null   int64
#  1   Partner           6338 non-null   int32
#  2   Dependents        6338 non-null   int32
#  3   tenure            6338 non-null   int64
#  4   OnlineSecurity    6338 non-null   int32
#  5   OnlineBackup      6338 non-null   int32
#  6   DeviceProtection  6338 non-null   int32
#  7   TechSupport       6338 non-null   int32
#  8   Contract          6338 non-null   int32
#  9   PaperlessBilling  6338 non-null   int32
#  10  PaymentMethod     6338 non-null   int32
#  11  MonthlyCharges    6338 non-null   float64
#  12  TotalCharges      6338 non-null   float64
#  13  Churn             6338 non-null   int64
# dtypes: float64(2), int32(9), int64(3)
# memory usage: 470.5 KB

# %%
# For chi-square (include all columns)
X_chi2 = data.drop(columns=['Churn'])

# For ANOVA (include only numerical columns)
X_anova = data.select_dtypes(include=['int64', 'float64','uint8']).drop(columns=['Churn'])

y = telecom_dataFrame['Churn']

# %%
from sklearn.feature_selection import SelectKBest, chi2, f_classif

# chi-square
top_chi2_features = SelectKBest(chi2, k=4).fit_transform(X_chi2, y)
chi2_feature_names = X_chi2.columns[SelectKBest(chi2, k=4).fit(X_chi2, y).get_support()]

# ANOVA
top_anova_features = SelectKBest(f_classif, k=4).fit_transform(X_anova, y)
anova_feature_names = X_anova.columns[SelectKBest(f_classif, k=4).fit(X_anova, y).get_support()]

# Create DataFrames for selected features
selected_features_df = pd.DataFrame({
    'Chi-Square Features': chi2_feature_names,
    'ANOVA Features': anova_feature_names
})

# Print the DataFrame
print(selected_features_df)
# Out:
#   Chi-Square Features  ANOVA Features
# 0              tenure   SeniorCitizen
# 1            Contract          tenure
# 2      MonthlyCharges  MonthlyCharges
# 3        TotalCharges    TotalCharges

# %%
from sklearn.feature_selection import SelectKBest, chi2, f_classif

# chi-square
print("Chi-Square:",top_chi2_features)

# or ANOVA
print("ANOVA:",top_anova_features)
# Out:
# Chi-Square: [[2.60000e+01 0.00000e+00 2.09000e+01 5.18300e+02]
#  [1.00000e+00 0.00000e+00 1.99000e+01 1.99000e+01]
#  [1.80000e+01 0.00000e+00 7.85500e+01 1.42265e+03]
#  ...
#  [1.20000e+01 0.00000e+00 2.11500e+01 3.06050e+02]
#  [1.20000e+01 0.00000e+00 9.94500e+01 1.20015e+03]
#  [2.60000e+01 1.00000e+00 1.98000e+01 4.57300e+02]]
# ANOVA: [[0.00000e+00 2.60000e+01 2.09000e+01 5.18300e+02]
#  [0.00000e+00 1.00000e+00 1.99000e+01 1.99000e+01]
#  [1.00000e+00 1.80000e+01 7.85500e+01 1.42265e+03]
#  ...
#  [0.00000e+00 1.20000e+01 2.11500e+01 3.06050e+02]
#  [1.00000e+00 1.20000e+01 9.94500e+01 1.20015e+03]
#  [0.00000e+00 2.60000e+01 1.98000e+01 4.57300e+02]]

# %% [markdown]
# From the Chi-Square test, 'tenure' and 'Contract' were identified as significant features, while in the ANOVA test, 'SeniorCitizen', 'tenure', 'MonthlyCharges', and 'TotalCharges' were deemed significant.
#
# Chi-Square features: 'tenure' and 'Contract' were selected, indicating their strong association with the target variable.
# ANOVA features: 'SeniorCitizen', 'tenure', 'MonthlyCharges', and 'TotalCharges' were identified, suggesting their significant impact on the target variable.
# Overall, these selected features provide valuable insights into the factors influencing the target variable, aiding in building more accurate predictive models.

# %%
display(data.head())
# Out:
#    SeniorCitizen  Partner  Dependents  tenure  OnlineSecurity  OnlineBackup  \
# 0              0        0           0      26               1             1
# 1              0        0           0       1               1             1
# 2              1        1           0      18               0             0
# 3              1        0           0      15               0             2
# 4              0        0           0       2               1             1
#
#    DeviceProtection  TechSupport  Contract  PaperlessBilling  PaymentMethod  \
# 0                 1            1         0                 0              3
# 1                 1            1         0                 0              3
# 2                 0            0         0                 0              2
# 3                 0            0         0                 1              1
# 4                 1            1         0                 1              3
#
#    MonthlyCharges  TotalCharges  Churn
# ...

# %% [markdown]
# ## Modeling
#
# Training at least three different classifier models (e.g., XGBoost, Random Forest, Decision Tree Classifier etc.) and optimize hyperparameters(Hint : GridsearchCV) to enhance performance.
#
# Implementing a validation pipeline utilizing 5-fold cross-validation. For each classifier, report F1 score, Cross-validation score, Precision, Recall, Accuracy). Also, for each model, plot the ROC-AUC curve.
#
# Then, combine your classifiers into an ensemble that outperforms each individual classifier. Describe and discuss your findings.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier


# Splitting data into features (X) and target variable (y)
X = data.drop(columns=['Churn'])
y = data['Churn']

# %%
from imblearn.combine import SMOTEENN

sm = SMOTEENN()

X_res, y_res = sm.fit_resample(X,y)

X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4207, 13)
# (1052, 13)
# (4207,)
# (1052,)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# 1. Train Random Forest Classifier and optimize hyperparameters
rf_param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': range(1,10),
}

rf = RandomForestClassifier()
rf_grid_search = GridSearchCV(estimator=rf, param_grid=rf_param_grid, scoring='accuracy', cv=5)
rf_grid_search.fit(X_train, y_train)


# Print best parameters and best scores for Random Forest classifier
print("Random Forest Best Parameters:", rf_grid_search.best_params_)
print("Random Forest Best Score:", rf_grid_search.best_score_)
# Out:
# Random Forest Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Random Forest Best Score: 0.9541220298197203

# %%
# 2. Train XGBoost Classifier and optimize hyperparameters
xgb_param_grid = {
    'learning_rate': [0.01, 0.1, 0.3],
    'max_depth': [3, 5, 7],
    'n_estimators':[100,200,300]
}

xgb = XGBClassifier()
xgb_grid_search = GridSearchCV(estimator=xgb, param_grid=xgb_param_grid, scoring='accuracy', cv=5)
xgb_grid_search.fit(X_train, y_train)


print("XGBoost Best Parameters:", xgb_grid_search.best_params_)
print("XGBoost Best Score:", xgb_grid_search.best_score_)
# Out:
# XGBoost Best Parameters: {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 300}
# XGBoost Best Score: 0.9574508347431656

# %%
# 3. Train Decision Tree Classifier and optimize hyperparameters
dt_param_grid = {
    'max_depth': range(1,30),
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

dt = DecisionTreeClassifier()
dt_grid_search = GridSearchCV(estimator=dt, param_grid=dt_param_grid, scoring='accuracy', cv=5)
dt_grid_search.fit(X_train, y_train)

print("Decision Tree Best Parameters:", dt_grid_search.best_params_)
print("Decision Tree Best Score:", dt_grid_search.best_score_)
# Out:
# Decision Tree Best Parameters: {'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Decision Tree Best Score: 0.9379592782034735

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

def evaluate_classifier(classifier, X_train, y_train, X_test, y_test, classifier_name):
    # Fit the classifier on the training data
    classifier.fit(X_train, y_train)
    
    # Cross-validation scores
    cv_scores = cross_val_score(classifier, X_train, y_train, cv=5, scoring='accuracy')
    
    # Calculate mean cross-validation scores
    print(f"{classifier_name} Cross-Validation Scores: {cv_scores.mean()}")

    # Make predictions on test data
    y_pred = classifier.predict(X_test)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    # Print evaluation metrics
    print(f"{classifier_name} Evaluation Metrics:")
    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"F1 Score: {f1}")
    
    # Plot ROC-AUC curve
    y_proba = classifier.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_proba)
    plt.plot(fpr, tpr, label=f'{classifier_name} (AUC = {roc_auc_score(y_test, y_proba):.2f})')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve - {classifier_name}')
    plt.legend()
    plt.show()

# %%
# Train and evaluate Random Forest Classifier
rf = RandomForestClassifier(**rf_grid_search.best_params_)
rf.fit(X_train, y_train)
evaluate_classifier(rf,X_train, y_train,X_test, y_test, "Random Forest")
# Out:
# Random Forest Cross-Validation Scores: 0.951984545036025
# Random Forest Evaluation Metrics:
# Accuracy: 0.9401140684410646
# Precision: 0.9222797927461139
# Recall: 0.967391304347826
# F1 Score: 0.9442970822281168

# %% [markdown]
# The Random Forest model achieves a best score of 0.954, indicating its overall effectiveness. Additionally, during cross-validation, the model maintains a high average score of 0.952, demonstrating consistent performance across different subsets of the data.
#
# The evaluation metrics further assess the model's performance on a specific test dataset. The model achieves an accuracy of 0.940, indicating the proportion of correctly classified instances. Precision, recall, and F1 score provide additional insights into the model's performance, with high values indicating a well-performing model that effectively balances precision and recall across different classes. Overall, these metrics suggest that the Random Forest model performs well in accurately classifying instances and generalizes effectively to unseen data.

# %%
# Train and evaluate XGBoost Classifier
xgb = XGBClassifier(**xgb_grid_search.best_params_)
xgb.fit(X_train, y_train)
evaluate_classifier(xgb,X_train, y_train,X_test, y_test, "XGBoost")
# Out:
# XGBoost Cross-Validation Scores: 0.9574508347431656
# XGBoost Evaluation Metrics:
# Accuracy: 0.9515209125475285
# Precision: 0.9417989417989417
# Recall: 0.967391304347826
# F1 Score: 0.9544235924932976

# %% [markdown]
# The XGBoost model achieves a best score of 0.957, showcasing its overall effectiveness in predictive tasks. During cross-validation, the model maintains a high average score of 0.957, indicating consistent performance across different subsets of the data.
#
# The evaluation metrics further assess the model's performance on a specific test dataset. The model achieves an accuracy of 0.952, indicating the proportion of correctly classified instances. Precision, recall, and F1 score provide additional insights into the model's performance, with high values suggesting a well-performing model that effectively balances precision and recall across different classes.
#
# Overall, these metrics suggest that the XGBoost model performs exceptionally well in accurately classifying instances and generalizes effectively to unseen data, making it a strong candidate for predictive modeling tasks.

# %%
# Train and evaluate Decision Tree Classifier
dt = DecisionTreeClassifier(**dt_grid_search.best_params_)
dt.fit(X_train, y_train)
evaluate_classifier(dt,X_train, y_train,X_test, y_test, "Decision Tree")
# Out:
# Decision Tree Cross-Validation Scores: 0.9365341000562049
# Decision Tree Evaluation Metrics:
# Accuracy: 0.9230038022813688
# Precision: 0.8998302207130731
# Recall: 0.9601449275362319
# F1 Score: 0.9290096406660825

# %% [markdown]
# The Decision Tree model achieves a best score of 0.938, demonstrating its effectiveness in making predictions. During cross-validation, the model maintains a high average score of 0.937, indicating consistent performance across different subsets of the data.
#
# The evaluation metrics further evaluate the model's performance on a specific test dataset. The model achieves an accuracy of 0.923, indicating the proportion of correctly classified instances. Precision, recall, and F1 score provide additional insights into the model's performance, with high values suggesting a well-performing model that effectively balances precision and recall across different classes.
#
# Overall, these metrics suggest that the Decision Tree model performs well in accurately classifying instances and generalizes effectively to unseen data. However, compared to other models like XGBoost, its performance might be slightly lower, but it still remains a viable option for certain predictive modeling tasks.

# %%
from sklearn.ensemble import VotingClassifier

# Create a Voting Classifier with the best performing models
voting_clf = VotingClassifier(estimators=[
    ('random_forest', rf),
    ('xgboost', xgb),
    ('decision_tree', dt)
])

grid = {
    'voting':['soft'],
}

grid_voting = GridSearchCV(estimator = voting_clf, param_grid=grid, scoring='accuracy', cv=5, n_jobs=-1)


# Train the Voting Classifier
grid_voting.fit(X_train, y_train)

print("Best Parameter:",grid_voting.best_params_)
print("Best Accuracy Score:",grid_voting.best_score_)

# Evaluate the Voting Classifier
evaluate_classifier(grid_voting, X_train, y_train,X_test, y_test, "Voting Classifier")
# Out:
# Best Parameter: {'voting': 'soft'}
# Best Accuracy Score: 0.954599066262593
# Voting Classifier Cross-Validation Scores: 0.9543609716969674
# Voting Classifier Evaluation Metrics:
# Accuracy: 0.94106463878327
# Precision: 0.9209621993127147
# Recall: 0.9710144927536232
# F1 Score: 0.9453262786596119

# %% [markdown]
# The Voting Classifier achieves a best accuracy score of 0.955, demonstrating its effectiveness in making accurate predictions. During cross-validation, the model maintains a high average score of 0.954, indicating consistent performance across different subsets of the data.
#
# The evaluation metrics further assess the model's performance on a specific test dataset. The model achieves an accuracy of 0.941, indicating the proportion of correctly classified instances. Precision, recall, and F1 score provide additional insights into the model's performance, with high values suggesting a well-performing model that effectively balances precision and recall across different classes.
#
# Overall, these metrics suggest that the Voting Classifier performs well in accurately classifying instances and generalizes effectively to unseen data, leveraging the strengths of multiple base models to improve predictive performance.

# %% [markdown]
# ##  Evaluation and Reporting
#
# Selecting a model that is expected to perform optimally on the unseen data and provide the predictions accordingly. Give clear conclusions

# %% [markdown]
# Based on the provided results, we have evaluated three different models: Decision Tree, Random Forest, and XGBoost. Among these, the XGBoost model demonstrated the highest accuracy of 0.952 and a balanced accuracy of 0.951 on the test dataset, outperforming both the Decision Tree and Random Forest models in terms of overall predictive performance.
#
# While the Decision Tree model achieved an accuracy of 0.923 and a balanced accuracy of 0.922, and the Random Forest model attained an accuracy of 0.940 and a balanced accuracy of 0.939, both fell slightly short compared to the XGBoost model.
#
# Considering the superior accuracy and balanced accuracy achieved by the XGBoost model, it is expected to perform optimally on unseen data. Therefore, we conclude that the XGBoost model should be selected for making predictions on new data due to its superior performance in accurately classifying room types.

# %%
from sklearn.metrics import balanced_accuracy_score

def evaluation_metrics(y_test, y_pred):
    # Calculate the balanced accuracy score
    balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
    return balanced_accuracy

# %%
# Train and evaluate XGBoost Classifier
xgb_classifier = XGBClassifier(learning_rate= 0.3, max_depth= 3, n_estimators=300)
xgb_classifier.fit(X_train, y_train)
y_pred = xgb_classifier.predict(X_test)
print(f"Accuracy wrt AccuracyScore: {accuracy_score(y_test, y_pred)}")
print(f"Balanced Accuracy: {evaluation_metrics(y_test, y_pred)}")
# Out:
# Accuracy wrt AccuracyScore: 0.9515209125475285
# Balanced Accuracy: 0.950695652173913

# %% [markdown]
# The evaluation on the test dataset yielded a high accuracy score and balanced accuracy, indicating strong performance in classifying room types. This suggests that the XGBoost model effectively leverages boosting techniques to improve predictive accuracy and generalization to unseen data. The combination of optimized parameters and the inherent strengths of the XGBoost algorithm likely contributed to the model's success in accurately predicting room types. Therefore, the XGBoost Classifier is considered a reliable choice for making predictions on similar datasets.

# %% [markdown]
# ## External validation
#
# A dataset named ‘test.csv’ is provided to you in which the label is hidden. You have to choose the best model(the model which has the highest score) and then use that model to predict the label on the ‘test.csv’.
#
# After prediction, you will get an array of 0’s and 1’s. Convert that array to csv file, name it as ‘submission.csv’ and submit that ‘submission.csv’ file.

# %%
'''
# This is psudo-code. Each student have to use their actual code for this.

# step 1. Load the  data
test = pd.read_csv('./data/test.csv')

# step 2. Pre-process the test data. You can use the same pre processing methods which you used for the train dataset earlier
x_test = preprocess_data(test)

# step 3. Choose the best model
your_best_model = some_model

# step 4. Make predictions
pred = your_best_model(x_test)

# step 5. Save output as csv file
pred = pd.DataFrame(pred)
pred.to_csv('./submission.csv', index = False)

'''

# %%
test_dataFrame = pd.read_csv('test.csv')
test_dataFrame
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    1024-GUALD  Female              0     Yes         No       1
# 1    0484-JPBRU    Male              0      No         No      41
# 2    3620-EHIMZ  Female              0     Yes        Yes      52
# 3    6910-HADCM  Female              0      No         No       1
# 4    8587-XYZSF    Male              0      No         No      67
# ..          ...     ...            ...     ...        ...     ...
# 700  4568-KNYWR    Male              0      No         No      52
# 701  9658-WYUFB  Female              0      No         No      17
# 702  0997-YTLNY  Female              0      No        Yes      19
# 703  3208-YPIOE    Male              0      No         No      39
# 704  7707-PYBBH    Male              0      No         No      40
#
#     PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 0             No  No phone service             DSL                   No
# ...

# %%
test_dataFrame.shape
# Out:
# (705, 20)

# %%
test_dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        705 non-null    object
#  1   gender            705 non-null    object
#  2   SeniorCitizen     705 non-null    int64
#  3   Partner           705 non-null    object
#  4   Dependents        705 non-null    object
#  5   tenure            705 non-null    int64
#  6   PhoneService      705 non-null    object
#  7   MultipleLines     705 non-null    object
#  8   InternetService   705 non-null    object
#  9   OnlineSecurity    705 non-null    object
#  10  OnlineBackup      705 non-null    object
#  11  DeviceProtection  705 non-null    object
#  12  TechSupport       705 non-null    object
#  13  StreamingTV       705 non-null    object
#  14  StreamingMovies   705 non-null    object
#  15  Contract          705 non-null    object
# ...

# %%
test_dataFrame["PaymentMethod"].unique()
# Out:
# array(['Electronic check', 'Bank transfer (automatic)', 'Mailed check',
#        'Credit card (automatic)'], dtype=object)

# %%
# Delete "automatic" from PaymentMethod
test_dataFrame["PaymentMethod"] = test_dataFrame["PaymentMethod"].str.replace(" (automatic)", "", regex=False)

# %%
test_dataFrame.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# dtype: int64

# %%
# filling the columns, which had missing values
mean_total_charges = test_dataFrame['TotalCharges'].mean()
test_dataFrame.fillna(mean_total_charges,inplace=True)

# %%
# Convert categorical values to numerical values using LabelEncoder
from sklearn.preprocessing import LabelEncoder

cat = test_dataFrame.select_dtypes(include='object')

label_encoder = LabelEncoder()
for col in cat:
    test_dataFrame[col]=label_encoder.fit_transform(test_dataFrame[col])

# %%
test_dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        705 non-null    int32
#  1   gender            705 non-null    int32
#  2   SeniorCitizen     705 non-null    int64
#  3   Partner           705 non-null    int32
#  4   Dependents        705 non-null    int32
#  5   tenure            705 non-null    int64
#  6   PhoneService      705 non-null    int32
#  7   MultipleLines     705 non-null    int32
#  8   InternetService   705 non-null    int32
#  9   OnlineSecurity    705 non-null    int32
#  10  OnlineBackup      705 non-null    int32
#  11  DeviceProtection  705 non-null    int32
#  12  TechSupport       705 non-null    int32
#  13  StreamingTV       705 non-null    int32
#  14  StreamingMovies   705 non-null    int32
#  15  Contract          705 non-null    int32
# ...

# %%
# dropping unwanted attributes, which were dropped in Training data
test_dataFrame.drop(columns=['customerID','gender','PhoneService','MultipleLines','InternetService','StreamingTV','StreamingMovies'], inplace=True)

# %%
display(test_dataFrame.head())
# Out:
#    SeniorCitizen  Partner  Dependents  tenure  OnlineSecurity  OnlineBackup  \
# 0              0        1           0       1               0             0
# 1              0        0           0      41               1             1
# 2              0        1           1      52               1             1
# 3              0        0           0       1               0             0
# 4              0        0           0      67               0             0
#
#    DeviceProtection  TechSupport  Contract  PaperlessBilling  PaymentMethod  \
# 0                 0            0         0                 1              2
# 1                 1            1         0                 1              0
# 2                 1            1         2                 0              3
# 3                 2            0         0                 0              2
# 4                 0            2         2                 0              0
#
#    MonthlyCharges  TotalCharges
# ...

# %%
for feature in test_dataFrame.columns:
    unique_values = test_dataFrame[feature].unique()
    print(f"Unique values in {feature}: {unique_values}")
# Out:
# Unique values in SeniorCitizen: [0 1]
# Unique values in Partner: [1 0]
# Unique values in Dependents: [0 1]
# Unique values in tenure: [ 1 41 52 67 68 23 72 70 34 28 18 15 11 37 22 46 51  5 45 29 50 27 60 17
#  33 66 69 57  8 14 25  7 13 19 59  9  3 10 39 54 35 12 31 53 30 48 38 65
#  24 40 43 71 61 26 42 21 56  4  6 55  2 44 62 63 49 20 16 47 32 64 58 36]
# Unique values in OnlineSecurity: [0 1 2]
# Unique values in OnlineBackup: [0 1 2]
# Unique values in DeviceProtection: [0 1 2]
# Unique values in TechSupport: [0 1 2]
# Unique values in Contract: [0 2 1]
# Unique values in PaperlessBilling: [1 0]
# Unique values in PaymentMethod: [2 0 3 1]
# Unique values in MonthlyCharges: [ 24.8   25.25  19.35  76.35  50.55  89.6   77.15  72.1  104.    19.4
#   20.45  84.05  51.    85.45  95.15  53.75  70.    88.8   89.4   70.25
#   19.45  80.   107.45 104.45  67.95  89.3   60.2   91.5   63.7  103.95
#   20.6   85.15  69.75  94.1   21.15 104.4  104.9  100.75  75.75  51.45
# ...

# %%
#MinMaxScaler can make numerical variables scaled from the range 0 to 1.

from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
features_mms = ["tenure","MonthlyCharges","TotalCharges"]

df_mms = pd.DataFrame(df_ohe, columns=features_mms)
df_remaining = df_ohe.drop(columns=features_mms)

mms = MinMaxScaler(feature_range=(0,1))
rescaled_feature = mms.fit_transform(df_mms)

rescaled_feature_df = pd.DataFrame(rescaled_feature, columns=features_mms, index=df_remaining.index)
df = pd.concat([rescaled_feature_df,df_remaining],axis=1)

# %%
test_dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SeniorCitizen     705 non-null    int64
#  1   Partner           705 non-null    int32
#  2   Dependents        705 non-null    int32
#  3   tenure            705 non-null    int64
#  4   OnlineSecurity    705 non-null    int32
#  5   OnlineBackup      705 non-null    int32
#  6   DeviceProtection  705 non-null    int32
#  7   TechSupport       705 non-null    int32
#  8   Contract          705 non-null    int32
#  9   PaperlessBilling  705 non-null    int32
#  10  PaymentMethod     705 non-null    int32
#  11  MonthlyCharges    705 non-null    float64
#  12  TotalCharges      705 non-null    float64
# dtypes: float64(2), int32(9), int64(2)
# memory usage: 46.9 KB

# %%
xgb_classifier = XGBClassifier(learning_rate= 0.3, max_depth= 3, n_estimators=300)
xgb_classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=300, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_pred = xgb_classifier.predict(test_dataFrame)
predict_labels = ['Yes' if pre==1 else 'No' for pre in y_pred]

# %%
pred_df = pd.DataFrame({'Churn': predict_labels})
pred_df.to_csv('submission.csv', index = False)

# %%
pred_df.shape
# Out:
# (705, 1)

# %% [markdown]
# ## Final evaluation metrics

# %%
from sklearn.metrics import balanced_accuracy_score

def evaluation_metrics(y_test, y_pred):
    # Calculate the balanced accuracy score
    balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
    return balanced_accuracy
